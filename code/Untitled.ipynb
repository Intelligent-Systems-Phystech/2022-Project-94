# %%
import xarray as xr 
import glob

aerology_path = "data/Texas_gribs/cutted_aerology"
land_path = "data/Texas_gribs/land"
runoff_path = "data/Texas_gribs/runoff_only"

apaths = glob.glob(aerology_path + "/*.grib")
lpaths = glob.glob(land_path + "/*.grib")
rpaths = glob.glob(runoff_path + "/*.grib")

# %%
ds = xr.open_dataset(lpaths[0], engine="cfgrib")
ds
# Out:
# skipping variable: paramId==205 shortName='ro'
# Traceback (most recent call last):
#   File "E:\anaconda\envs\hail_project\lib\site-packages\cfgrib\dataset.py", line 660, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "E:\anaconda\envs\hail_project\lib\site-packages\cfgrib\dataset.py", line 591, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='time' value=Variable(dimensions=('time',), data=array([1577836800, 1577858400, 1577880000, ..., 1640930400, 1640952000,
#        1640973600])) new_value=Variable(dimensions=('time',), data=array([1577815200, 1577858400, 1577901600, ..., 1640844000, 1640887200,
#        1640930400]))
# <xarray.Dataset>
# Dimensions:     (time: 2924, latitude: 41, longitude: 65)
# Coordinates:
#     number      int32 ...
#   * time        (time) datetime64[ns] 2020-01-01 ... 2021-12-31T18:00:00
#     step        timedelta64[ns] ...
# ...

# %%
ds["d2m"]
# Out:
# <xarray.DataArray 'd2m' (time: 2924, latitude: 41, longitude: 65)>
# [7792460 values with dtype=float32]
# Coordinates:
#     number      int32 0
#   * time        (time) datetime64[ns] 2020-01-01 ... 2021-12-31T18:00:00
#     step        timedelta64[ns] 00:00:00
#     surface     float64 0.0
#   * latitude    (latitude) float64 37.0 36.75 36.5 36.25 ... 27.5 27.25 27.0
#   * longitude   (longitude) float64 -109.0 -108.8 -108.5 ... -93.5 -93.25 -93.0
#     valid_time  (time) datetime64[ns] 2020-01-01 ... 2021-12-31T18:00:00
# Attributes:
#     GRIB_paramId:                             168
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      2665
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     GRIB_gridType:                            regular_ll
#     GRIB_NV:                                  0
# ...

# %%
"step" in ds.dims
# Out:
# True

# %%
import datetime as dt
timedelta = ds.time.to_numpy()[1].astype('datetime64[h]') - ds.time.to_numpy()[0].astype('datetime64[h]')
dir(timedelta)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_interface__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__class_getitem__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
# ...

# %%
timedelta.astype("int")
# Out:
# 6

# %%
ds.dims["time"]
# Out:
# 2924

# %%
ds.dims["longitude"]
# Out:
# 65

# %%
ds.dims
# Out:
# Frozen({'time': 2924, 'isobaricInhPa': 3, 'latitude': 41, 'longitude': 65})

# %%
import src.data_processing as dp

# %%
one_day_train_data = dp.prepare_train_data(apaths[0], [], one_day=False)
# Out:
# Ignoring index file 'data/Texas_gribs/cutted_aerology\\adaptor.mars.internal-1657555490.0866394-25715-6-f2c5a5d2-4ce8-4a48-ad21-5bfc352828a1.grib.923a8.idx' incompatible with GRIB file
# collecting all variables from the dataset

# %%
one_day_train_data.shape
# Out:
# (731, 60, 65, 41)
